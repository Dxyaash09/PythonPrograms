# %%
for i in range(1,21):
    if(i%2==0):
        continue
    else:
        print(f"odd no is={i}")
        i=i+1
# Out:
# odd no is=1
# odd no is=3
# odd no is=5
# odd no is=7
# odd no is=9
# odd no is=11
# odd no is=13
# odd no is=15
# odd no is=17
# odd no is=19
